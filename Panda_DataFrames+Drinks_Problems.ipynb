# %% [markdown]
# <a href="https://colab.research.google.com/github/SpectreB/Python-class/blob/main/Panda_DataFrames%2BDrinks_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
person_1 = {
    "first" : "Mit",
    "last" : "Patel",
    "mail" : "tuconnais@gmail.com"

}

# %%
df1 = pd.DataFrame(person_1, index = [0])

# %%
import pandas as pd

# %%
people_2 = {
    "first": ["Mit"],
    "last": ["Patel"],
    "email": ["mitpatel@gmail.com"]
}

# %%
df2 = pd.DataFrame(people_2, index = [0])

# %%
people = {
    "first": ["Mit", 'Rowland', 'vish'],
    "last": ["Patel", 'Doe', 'Doe'],
    "email": ["mitpatel@gmail.com", 'rowlanddoe@email.com', 'vishdoe@email.com']
}

# %%
people['email']
# Out:
# ['mitpatel@gmail.com', 'rowlanddoe@email.com', 'vishdoe@email.com']

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#      first   last                 email
# 0      Mit  Patel    mitpatel@gmail.com
# 1  Rowland    Doe  rowlanddoe@email.com
# 2     vish    Doe     vishdoe@email.com

# %%
df.iloc[[0, 1], 2]
# Out:
# 0      mitpatel@gmail.com
# 1    rowlanddoe@email.com
# Name: email, dtype: object

# %%
df[['last', 'email']]
# Out:
#     last                 email
# 0  Patel    mitpatel@gmail.com
# 1    Doe  rowlanddoe@email.com
# 2    Doe     vishdoe@email.com

# %%
df['email']
# Out:
# 0      mitpatel@gmail.com
# 1    rowlanddoe@email.com
# 2       vishdoe@email.com
# Name: email, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-1ece190fb3c5> in <cell line: 1>()
# ----> 1 index(['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com'], dtype='object', name='email')
#
# NameError: name 'index' is not defined

# %%
df_1 = pd.DataFrame({'month': [1, 4, 7, 10],
                   'year': [2012, 2014, 2013, 2014],
                   'sale': [55, 40, 84, 31]})

# %%
df_1
# Out:
#    month  year  sale
# 0      1  2012    55
# 1      4  2014    40
# 2      7  2013    84
# 3     10  2014    31

# %%
df_1.set_index(['year', 'month'])
# Out:
#             sale
# year month
# 2012 1        55
# 2014 4        40
# 2013 7        84
# 2014 10       31

# %%
df_1.set_index([pd.Index([1, 2, 3, 4]), 'year'])
# Out:
#         month  sale
#   year
# 1 2012      1    55
# 2 2014      4    40
# 3 2013      7    84
# 4 2014     10    31

# %%
s = pd.Series([1, 2, 3, 4])
df_1.set_index([s, s**2])
# Out:
#       month  year  sale
# 1 1       1  2012    55
# 2 4       4  2014    40
# 3 9       7  2013    84
# 4 16     10  2014    31

# %%
df
# Out:
#      first   last                 email
# 0      Mit  Patel    mitpatel@gmail.com
# 1  Rowland    Doe  rowlanddoe@email.com
# 2     vish    Doe     vishdoe@email.com

# %%
s = pd.Series([1, 2, 3, 4])
df_1.set_index([s, s**2])
# Out:
#       month  year  sale
# 1 1       1  2012    55
# 2 4       4  2014    40
# 3 9       7  2013    84
# 4 16     10  2014    31

# %%
df.columns
# Out:
# Index(['first', 'last', 'email'], dtype='object')

# %%
df.columns=['First_Name', 'Last_Name', 'Email']

# %%
df
# Out:
#   First_Name Last_Name                 Email
# 0        Mit     Patel    mitpatel@gmail.com
# 1    Rowland       Doe  rowlanddoe@email.com
# 2       vish       Doe     vishdoe@email.com

# %%
df.columns=[x.lower() for x in df.columns]

# %%
df.rename(columns={'first_name': 'first', 'last_name': 'last'}, inplace=True)

# %%
df.loc[2]=['John', 'Smith', 'johnsmith@email.com']

# %%
df
# Out:
#      first   last                 email
# 0      Mit  Patel    mitpatel@gmail.com
# 1  Rowland    Doe  rowlanddoe@email.com
# 2     John  Smith   johnsmith@email.com

# %%
df.loc[2, ['last', 'email'] ] = ['Doe','johndoe@email.com']

# %%
df
# Out:
#      first   last                 email
# 0      Mit  Patel    mitpatel@gmail.com
# 1  Rowland    Doe  rowlanddoe@email.com
# 2     John    Doe     johndoe@email.com

# %%
df.loc[2, 'last'] = 'Smith'

# %%
df.at[2, 'last'] = 'Doe'

# %%
filt = (df['email'] == 'johndoe@email.com')
df.loc[filt, 'last'] = 'Smith'

# %%
df
# Out:
#      first   last                 email
# 0      Mit  Patel    mitpatel@gmail.com
# 1  Rowland    Doe  rowlanddoe@email.com
# 2     John  Smith     johndoe@email.com

# %%
df['first'] = df['first'].str.lower()

# %%
df
# Out:
#      first   last                 email
# 0      mit  Patel    mitpatel@gmail.com
# 1  rowland    Doe  rowlanddoe@email.com
# 2     john  Smith     johndoe@email.com

# %%
df['email'].apply(len)
# Out:
# 0    18
# 1    20
# 2    17
# Name: email, dtype: int64

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0      MITPATEL@GMAIL.COM
# 1    ROWLANDDOE@EMAIL.COM
# 2       JOHNDOE@EMAIL.COM
# Name: email, dtype: object

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
drink=pd.read_csv("/content/drinks.csv")
