# %% [markdown]
# <a href="https://colab.research.google.com/github/SpectreB/Python-class/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.5.3

# %%
df=pd.read_csv("/content/Educational_Attainment_20231027.csv")

# %%
pd.read_json
pd.read_csv
# Out:
# <function pandas.io.parsers.readers.read_csv(filepath_or_buffer: 'FilePath | ReadCsvBuffer[bytes] | ReadCsvBuffer[str]', *, sep: 'str | None | lib.NoDefault' = <no_default>, delimiter: 'str | None | lib.NoDefault' = None, header: "int | Sequence[int] | None | Literal['infer']" = 'infer', names: 'Sequence[Hashable] | None | lib.NoDefault' = <no_default>, index_col: 'IndexLabel | Literal[False] | None' = None, usecols=None, squeeze: 'bool | None' = None, prefix: 'str | lib.NoDefault' = <no_default>, mangle_dupe_cols: 'bool' = True, dtype: 'DtypeArg | None' = None, engine: 'CSVEngine | None' = None, converters=None, true_values=None, false_values=None, skipinitialspace: 'bool' = False, skiprows=None, skipfooter: 'int' = 0, nrows: 'int | None' = None, na_values=None, keep_default_na: 'bool' = True, na_filter: 'bool' = True, verbose: 'bool' = False, skip_blank_lines: 'bool' = True, parse_dates=None, infer_datetime_format: 'bool' = False, keep_date_col: 'bool' = False, date_parser=None, da
# ...

# %%
df.head(5)
# Out:
#         Geography Geography type  Year  Less Than High School Graduate  \
# 0        Atherton           Town  2014                            13.6
# 1           Colma           Town  2014                             6.3
# 2     Foster City           City  2014                            11.9
# 3  Portola Valley           Town  2014                            48.1
# 4    Redwood City           City  2014                            16.4
#
#    High School Graduate  Some College or Associate's Degree  \
# 0                  12.3                                 2.7
# 1                   6.4                                10.4
# 2                   9.7                                 2.0
# 3                   0.0                                 0.0
# 4                  10.6                                 6.6
#
#    Bachelor's Degree or Higher                Location 1
# 0                          3.5       (37.458611, -122.2)
# 1                          2.4  (37.678889, -122.455556)
# ...

# %%
df.tail(10)
# Out:
#           Geography Geography type  Year  Less Than High School Graduate  \
# 22         Loma Mar            CDP  2014                           100.0
# 23         Woodside           Town  2014                             0.0
# 24    Half Moon Bay           City  2014                             9.5
# 25        San Bruno           City  2014                             7.7
# 26        Pescadero            CDP  2014                            44.4
# 27       El Granada            CDP  2014                             9.2
# 28  West Menlo Park            CDP  2014                            37.8
# 29          Montara            CDP  2014                             3.3
# 30       Burlingame           City  2014                            20.1
# 31         La Honda            CDP  2014                             0.0
#
#     High School Graduate  Some College or Associate's Degree  \
# 22                   0.0                                 0.0
# ...

# %%
df.describe()
# Out:
#          Year  Less Than High School Graduate  High School Graduate  \
# count    32.0                        32.00000             32.000000
# mean   2014.0                        17.80000              6.462500
# std       0.0                        19.29944              4.693905
# min    2014.0                         0.00000              0.000000
# 25%    2014.0                         6.82500              1.925000
# 50%    2014.0                        13.90000              7.750000
# 75%    2014.0                        20.97500              9.450000
# max    2014.0                       100.00000             16.400000
#
#        Some College or Associate's Degree  Bachelor's Degree or Higher
# count                           32.000000                    32.000000
# mean                             5.946875                     2.856250
# std                              4.728430                     1.873919
# min                              0.000000                     0.000000
# ...

# %%
df.drop("Geography", axis=1).describe(include="all")
# Out:
#        Geography type    Year  Less Than High School Graduate  \
# count              32    32.0                        32.00000
# unique              3     NaN                             NaN
# top              City     NaN                             NaN
# freq               15     NaN                             NaN
# mean              NaN  2014.0                        17.80000
# std               NaN     0.0                        19.29944
# min               NaN  2014.0                         0.00000
# 25%               NaN  2014.0                         6.82500
# 50%               NaN  2014.0                        13.90000
# 75%               NaN  2014.0                        20.97500
# max               NaN  2014.0                       100.00000
#
#         High School Graduate  Some College or Associate's Degree  \
# count              32.000000                           32.000000
# unique                   NaN                                 NaN
# ...

# %%
df.dttypes

# %%
df.Geography.count()
# Out:
# 32

# %%
df.columns = df.columns.str.replace(' ' ,'')
df.columns= df.columns.str.replace("'", "")
# Out:
#                   Geography Geographytype  Year  LessThanHighSchoolGraduate  \
# 0                 Atherton          Town  2014                        13.6
# 1                    Colma          Town  2014                         6.3
# 2              Foster City          City  2014                        11.9
# 3           Portola Valley          Town  2014                        48.1
# 4             Redwood City          City  2014                        16.4
# 5                   Ladera           CDP  2014                         0.0
# 6               Moss Beach           CDP  2014                         4.8
# 7      South San Francisco          City  2014                        14.2
# 8                  Belmont          City  2014                        20.9
# 9                Daly City          City  2014                        13.4
# 10               San Mateo          City  2014                        16.1
# ...

# %%
df.Geographytype.unique()
# Out:
# array(['Town', 'City', 'CDP'], dtype=object)

# %%
df.LessThanHighSchoolGraduate.value_counts()
# Out:
# 0.0      4
# 13.6     1
# 15.1     1
# 3.3      1
# 37.8     1
# 9.2      1
# 44.4     1
# 7.7      1
# 9.5      1
# 100.0    1
# 7.0      1
# 21.2     1
# 18.3     1
# 15.7     1
# 8.5      1
# 22.1     1
# 6.3      1
# 31.1     1
# 6.2      1
# 26.7     1
# 16.1     1
# 13.4     1
# 20.9     1
# 14.2     1
# 4.8      1
# 16.4     1
# 48.1     1
# 11.9     1
# 20.1     1
# Name: LessThanHighSchoolGraduate, dtype: int64

# %%
df2=pd.read_csv("/content/survey_results_schema.csv")

# %%
df.LessThanHighSchoolGraduate.value_counts()
# Out:
# 0.0      4
# 13.6     1
# 15.1     1
# 3.3      1
# 37.8     1
# 9.2      1
# 44.4     1
# 7.7      1
# 9.5      1
# 100.0    1
# 7.0      1
# 21.2     1
# 18.3     1
# 15.7     1
# 8.5      1
# 22.1     1
# 6.3      1
# 31.1     1
# 6.2      1
# 26.7     1
# 16.1     1
# 13.4     1
# 20.9     1
# 14.2     1
# 4.8      1
# 16.4     1
# 48.1     1
# 11.9     1
# 20.1     1
# Name: LessThanHighSchoolGraduate, dtype: int64

# %%
df2=pd.read_csv("/content/survey_results_schema.csv")

# %%
df2.shape
# Out:
# (78, 6)

# %%
pd.set_option("display.max_columns", 85)
pd.set_option("display.max_rows", 85)

# %%
d1=pd.read_csv("/content/survey_results_publica.csv")
d1.loc[0, 'MainBranch':'ToolsTechHaveWorkedWith']
d1.loc[0:5, 'MainBranch':'RemoteWork']
# Out:
#                        MainBranch              Age  \
# 0                   None of these  18-24 years old
# 1  I am a developer by profession  25-34 years old
# 2  I am a developer by profession  45-54 years old
# 3  I am a developer by profession  25-34 years old
# 4  I am a developer by profession  25-34 years old
# 5  I am a developer by profession  35-44 years old
#
#                                           Employment  \
# 0                                                NaN
# 1                                Employed, full-time
# 2                                Employed, full-time
# 3                                Employed, full-time
# 4  Employed, full-time;Independent contractor, fr...
# 5                                Employed, full-time
#
#                              RemoteWork
# 0                                   NaN
# 1                                Remote
# 2  Hybrid (some remote, some in-person)
# 3  Hybrid (some remote, some in-person)
# ...

# %%
def mapGeography(s) :
  if s=="Town" :
    return 1
  else :
    return 0

# %%
df['geography_mapped_value'] = df.Geographytype.apply(mapGeography)

# %%
baby_names=pd.read_csv("/content/US_Baby_Names_right.csv")

# %%
baby_names.head(10)
# Out:
#    Unnamed: 0     Id      Name    Year Gender State  Count
# 0       11349  11350      Emma  2004.0      F    AK   62.0
# 1       11350  11351   Madison  2004.0      F    AK   48.0
# 2       11351  11352    Hannah  2004.0      F    AK   46.0
# 3       11352  11353     Grace  2004.0      F    AK   44.0
# 4       11353  11354     Emily  2004.0      F    AK   41.0
# 5       11354  11355   Abigail  2004.0      F    AK   37.0
# 6       11355  11356    Olivia  2004.0      F    AK   33.0
# 7       11356  11357  Isabella  2004.0      F    AK   30.0
# 8       11357  11358    Alyssa  2004.0      F    AK   29.0
# 9       11358  11359    Sophia  2004.0      F    AK   28.0

# %%
del baby_names["Id"]

# %%
del baby_names["Unnamed: 0"]

# %%
'''def Parity(x) :

  nbMen=0
  nbWomen=0

  for i in range (x.length) :
    if i=='F' :
      nbWomen+=1
    else :
      nbMen+=1

  if NbWomen > nbMen :
'''

# %%
baby_names['Gender'].value_counts()
# Out:
# F    222058
# M    171960
# Name: Gender, dtype: int64

# %%
## 8
nb_unique_Name=baby_names["Name"].nunique()
print(f"number of different names in the dataset is : {nb_unique_Name}" )
# Out:
# number of different names in the dataset is : 14144

# %%
## 9
Name_with_most_occurence=baby_names["Name"].value_counts().idxmax()
print(f" the name with the most occurences is {Name_with_most_occurence} ")
# Out:
#  the name with the most occurences is Riley

# %%
"""
group by name
"""

names =baby_names.groupby("Name").sum()
# Out:
# <ipython-input-34-af74682ae55b>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   names =baby_names.groupby("Name").sum()

# %%
##10

"""
names_count=names.value_counts()
val_min_names_count=names_count.min()
List_of_mins_names=names[names['Name'].value_counts() == val_min_names_count]
print(f" the names with the least occurences are {List_of_mins_names} ")
"""
len(names[names.Count== names.Count.min()])
# Out:
# 2051

# %%
names[names.Count == names.Count.median()]
# Out:
#            Unnamed: 0         Id     Year  Count
# Name
# Alexsa        4845771  4845778.0  14049.0   44.0
# Amna          7097802  7097809.0  14065.0   44.0
# Arham         7303958  7303964.0  12068.0   44.0
# Arrow         3840416  3840421.0  10067.0   44.0
# Aryssa        3217786  3217792.0  12043.0   44.0
# Babyboy       4846158  4846163.0  10022.0   44.0
# Bellamy       6028708  6028715.0  14091.0   44.0
# Dajon         8042684  8042692.0  16057.0   44.0
# Davianna      8582744  8582752.0  16063.0   44.0
# Devean        2048571  2048574.0   6015.0   44.0
# Elexa         4069919  4069926.0  14055.0   44.0
# Emmersyn      8577977  8577985.0  16098.0   44.0
# Esabella      3817581  3817587.0  12064.0   44.0
# Favio         3453498  3453503.0  10038.0   44.0
# Jaclynn       3818036  3818043.0  14065.0   44.0
# Jakhari       7221878  7221885.0  14071.0   44.0
# Jayanna       6634776  6634783.0  14062.0   44.0
# Jennalyn      3769171  3769178.0  14053.0   44.0
# ...
